# %%
import crystal_toolkit
import os
from pymatgen.core import Structure
import matcalc

# %%
struct_expt = Structure.from_file(
    os.path.join("cif", "POSCAR_MnZn_1_relaxed")
)

# %%
calculator_pbe = matcalc.load_fp("pbe")

phonon_calc = matcalc.PhononCalc( # type: ignore
    calculator_pbe,
    relax_structure=True,
    write_band_structure="output/ZFO0_75_phonon_bs.yaml",
    write_total_dos="output/ZFO0_75_phonon_dos.dat",
    write_phonon="output/ZFO0_75_phonon.yaml",
    optimizer="FIRE",
)

final_structure_pbe =struct_expt

data_ZFO0_75 = phonon_calc.calc(final_structure_pbe)
# Out:
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.419157186484621e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.47216702011836e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.461756715823808e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.430499421523785e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.427195732478278e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.430125910116588e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.465046964728106e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.501629100260133e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.447408989321449e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.496908317326294e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.456319152238471e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.44645078222366e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.460410159088732e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.451671038849165e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.46929295116296e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.459409604177748e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.393615318466104e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.408467921403074e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.441518245225111e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.419063832421278e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.398990811456383e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.397611771873264e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.419180889250497e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.412082118406299e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.447026518134971e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.346137924072356e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.388907401342688e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.368718988398148e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.329246331510087e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.370784123136278e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.320087003869101e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.354304418963766e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.306791792514087e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.221708958664521e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.304207521063155e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.258333380306634e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.241332056845757e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.281375165358704e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.156880883085151e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.145348169759729e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.234794556932432e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.194124723395567e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.162604567956281e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.188668711264515e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.184140445757807e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.192732341198194e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.176539494265171e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.13179402456431e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.185927836170303e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.258717550327737e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.256942154667484e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.278815876898872e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.216642024774185e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.182109784765744e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.208867568360848e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.134972221395172e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\ase\filters.py:606: RuntimeWarning: logm result may be inaccurate, approximate err = 5.08840253227891e-13
#   pos[natoms:] = self.logm(pos[natoms:]) * self.exp_cell_factor
# c:\Users\Sabbir\miniconda3\envs\matsim\lib\site-packages\seekpath\hpkot\__init__.py:172: DeprecationWarning: dict interface is deprecated. Use attribute interface instead
#   conv_lattice = dataset["std_lattice"]

# %%
import matplotlib.pyplot as plt

phonon_bs = data_ZFO0_75['phonon'].band_structure

n_axes = sum(1 for c in phonon_bs.path_connections if not c)

fig, axs = plt.subplots(1, n_axes, figsize=(16, 5))

if n_axes == 1:
    axs = [axs]

for ax in axs[1:]:
    ax.set_ylabel('')
    ax.tick_params(axis='y', labelleft=False)

phonon_bs.plot(ax=axs)
fig.suptitle("Phonon band structure", fontsize=16)
plt.subplots_adjust(wspace=0.07)
plt.show()

# %%
phonon_dos = data_ZFO0_75["phonon"].total_dos

fig, ax = plt.subplots(figsize=(8, 5))
phonon_dos.plot(ax=ax)
fig.suptitle("Phonon DOS", fontsize=16)
plt.show()

# %%
plt.plot(
    data_ZFO0_75['thermal_properties']['temperatures'],
    data_ZFO0_75['thermal_properties']['heat_capacity']
)

plt.xlabel("Temperature (K)")
plt.ylabel('Heat Capacity (J/mol-K)')
plt.title("Heat Capacity vs Temperature")
plt.show()

# %% [markdown]
# ## r2scan

# %%
## Relax with r2scan

import matcalc

calculator_r2scan = matcalc.load_fp("r2scan")
relax_calc = matcalc.RelaxCalc(
    calculator_r2scan,
    optimizer="FIRE",
    relax_atoms=True,
    relax_cell=True
)

data_r2scan = relax_calc.calc(struct_expt)

# %%
final_structure_r2scan = data_r2scan['final_structure']
print(final_structure_r2scan)
final_structure_r2scan
