# %%
from pymatgen.core import Structure

structure = Structure.from_file("Zn(FeO2)2_fd_relaxed.cif")

json_string = structure.to_json()
print(json_string)

structure.to(filename="Zn(FeO2)2_fd_relaxed.json")
# Out:
# {"@module": "pymatgen.core.structure", "@class": "Structure", "charge": 0.0, "lattice": {"matrix": [[8.1792, 0.0, 5.008315549793016e-16], [1.3153156776235145e-15, 8.1792, 5.008315549793016e-16], [0.0, 0.0, 8.1792]], "pbc": [true, true, true], "a": 8.1792, "b": 8.1792, "c": 8.1792, "alpha": 90.0, "beta": 90.0, "gamma": 90.0, "volume": 547.1828579450879}, "properties": {}, "sites": [{"species": [{"element": "Zn", "occu": 1.0}], "abc": [0.0, 0.5, 0.5], "properties": {}, "label": "Zn0", "xyz": [6.576578388117573e-16, 4.0896, 4.0896]}, {"species": [{"element": "Zn", "occu": 1.0}], "abc": [0.0, 0.0, 0.0], "properties": {}, "label": "Zn0", "xyz": [0.0, 0.0, 0.0]}, {"species": [{"element": "Zn", "occu": 1.0}], "abc": [0.5, 0.0, 0.5], "properties": {}, "label": "Zn0", "xyz": [4.0896, 0.0, 4.0896]}, {"species": [{"element": "Zn", "occu": 1.0}], "abc": [0.5, 0.5, 0.0], "properties": {}, "label": "Zn0", "xyz": [4.089600000000001, 4.0896, 5.008315549793016e-16]}, {"species": [{"element": "Zn", "o
# ...

# %%
import crystal_toolkit

sqs_structure = Structure.from_file("sqs-0-0.cif")
print(sqs_structure)
sqs_structure
# Out:
# Full Formula (Mn8 Zn32 Fe80 O160)
# Reduced Formula: MnZn4(FeO2)10
# abc   :  40.896000   8.179200   8.179200
# angles:  90.000000  90.000000  90.000000
# pbc   :       True       True       True
# Sites (280)
#   #  SP          a        b        c
# ---  ----  -------  -------  -------
#   0  Mn0+  0        0        0
#   1  Mn0+  0.4      0.5      0.5
#   2  Mn0+  0.1      0.5      0
#   3  Mn0+  0.25     0.25     0.25
#   4  Mn0+  0.8      0        0
#   5  Mn0+  0        0.5      0.5
#   6  Mn0+  0.5      0.5      0
#   7  Mn0+  0.45     0.75     0.75
#   8  Zn0+  0.1      0        0.5
#   9  Zn0+  0.05     0.25     0.25
#  10  Zn0+  0.15     0.25     0.75
#  11  Zn0+  0.15     0.75     0.25
#  12  Zn0+  0.05     0.75     0.75
#  13  Zn0+  0.2      0.5      0.5
#  14  Zn0+  0.2      0        0
#  15  Zn0+  0.3      0        0.5
#  16  Zn0+  0.3      0.5      0
#  17  Zn0+  0.35     0.25     0.75
#  18  Zn0+  0.35     0.75     0.25
#  19  Zn0+  0.25     0.75     0.75
# ...
